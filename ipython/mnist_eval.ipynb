# %%
import tensorflow as tf

import tensorflow.contrib.slim as slim
from mnist import inputs, lenet

# %%
flags = tf.app.flags
flags.DEFINE_string('train_dir', './data',
                    'Directory with the training data.')
flags.DEFINE_integer('batch_size', 5, 'Batch size.')
flags.DEFINE_integer('num_batches', 1000, 'Num of batches to evaluate.')
flags.DEFINE_string('log_dir', './log/eval',
                    'Directory where to log data.')
flags.DEFINE_string('checkpoint_dir', './log/train',
                    'Directory with the model checkpoint data.')
FLAGS = flags.FLAGS

# %%
images, labels = inputs(FLAGS.train_dir, False, FLAGS.batch_size, FLAGS.num_batches,one_hot_labels=False)
predictions = lenet(images)
# Out:
# image:  Tensor("input/Reshape:0", shape=(60, 80, 3), dtype=float32)
# label1:  Tensor("input/Reshape_1:0", shape=(1,), dtype=float32)
# label2:  Tensor("input/Reshape_1:0", shape=(1,), dtype=float32)
# images
# Tensor("input/shuffle_batch:0", shape=(5, 60, 80, 3), dtype=float32)

# %%
metrics_to_values, metrics_to_updates = slim.metrics.aggregate_metric_map({
    "streaming_mse": slim.metrics.streaming_mean_squared_error(predictions, labels),
})

# %%
metrics_to_values
# Out:
# {'streaming_mse': <tf.Tensor 'mean_squared_error/value:0' shape=() dtype=float32>}

# %%
metrics_to_updates
# Out:
# {'streaming_mse': <tf.Tensor 'mean_squared_error/update_op:0' shape=() dtype=float32>}

# %%
# for metric_name, metric_value in metrics_to_values.items():
tf.scalar_summary("metric_name", metrics_to_values['streaming_mse'])
# Out:
# <tf.Tensor 'ScalarSummary:0' shape=() dtype=string>

# %%
slim.evaluation.evaluation_loop(
    '',
    FLAGS.checkpoint_dir,
    FLAGS.log_dir,
    num_evals=FLAGS.num_batches,
    eval_op=metrics_to_updates['streaming_mse'],
    summary_op=tf.merge_all_summaries(),
    eval_interval_secs=30)

# %%
# predictions = tf.to_int32(tf.argmax(predictions, 1))

# tf.scalar_summary('accuracy', slim.metrics.streaming_mean_squared_error(predictions, labels))

# These are streaming metrics which compute the "running" metric,
# e.g running accuracy
# metrics_to_values, metrics_to_updates = slim.metrics.aggregate_metric_map({
#     "streaming_mse": slim.metrics.streaming_mean_squared_error(predictions, labels),
# })

# Define the streaming summaries to write:
# for metric_name, metric_value in metrics_to_values.items():
#     tf.scalar_summary(metric_name, metric_value)
    
    
names_to_values, names_to_updates = slim.metrics.aggregate_metric_map({
  "mse": slim.metrics.streaming_mean_squared_error(predictions, labels),
})
# Define the summaries to write:
for metric_name, metric_value in metrics_to_values.items():
    tf.scalar_summary(metric_name, metric_value)
checkpoint_dir = './log/train'
log_dir = './log/eval'
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-21-f7c5f6ef5cdd> in <module>()
#      17
#      18 names_to_values, names_to_updates = slim.metrics.aggregate_metric_map({
# ---> 19   "mse": slim.metrics.streaming_mean_squared_error(predictions, labels),
#      20 })
#      21 # Define the summaries to write:
#
# /Users/daniel/anaconda3/envs/tensorflow2/lib/python3.5/site-packages/tensorflow/contrib/metrics/python/ops/metric_ops.py in streaming_mean_squared_error(predictions, labels, weights, metrics_collections, updates_collections, name)
#    2241       predictions, labels)
#    2242   predictions.get_shape().assert_is_compatible_with(labels.get_shape())
# -> 2243   squared_error = math_ops.square(labels - predictions)
#    2244   return streaming_mean(squared_error, weights, metrics_collections,
#    2245                         updates_collections, name or 'mean_squared_error')
#
# /Users/daniel/anaconda3/envs/tensorflow2/lib/python3.5/site-packages/tensorflow/python/ops/math_ops.py in binary_op_wrapper(x, y)
#     749       if not isinstance(y, ops.SparseTensor):
#     750         y = ops.convert_to_tensor(y, dtype=x.dtype.base_dtype, name="y")
# --> 751       return func(x, y, name=name)
#     752
#     753   def binary_op_wrapper_sparse(sp_x, y):
#
# /Users/daniel/anaconda3/envs/tensorflow2/lib/python3.5/contextlib.py in __exit__(self, type, value, traceback)
#      75                 value = type()
#      76             try:
# ---> 77                 self.gen.throw(type, value, traceback)
#      78                 raise RuntimeError("generator didn't stop after throw()")
#      79             except StopIteration as exc:
#
# /Users/daniel/anaconda3/envs/tensorflow2/lib/python3.5/site-packages/tensorflow/python/framework/ops.py in name_scope(name, default_name, values)
#    4148   g = _get_graph_from_inputs(values)
#    4149   with g.as_default(), g.name_scope(n) as scope:
# -> 4150     yield scope
#    4151 # pylint: enable=g-doc-return-or-yield
#    4152
#
# /Users/daniel/anaconda3/envs/tensorflow2/lib/python3.5/contextlib.py in __exit__(self, type, value, traceback)
#      75                 value = type()
#      76             try:
# ---> 77                 self.gen.throw(type, value, traceback)
#      78                 raise RuntimeError("generator didn't stop after throw()")
#      79             except StopIteration as exc:
#
# /Users/daniel/anaconda3/envs/tensorflow2/lib/python3.5/site-packages/tensorflow/python/framework/ops.py in get_controller(self, default)
#    3643     try:
#    3644       self.stack.append(default)
# -> 3645       yield default
#    3646     finally:
#    3647       if self._enforce_nesting:
#
# /Users/daniel/anaconda3/envs/tensorflow2/lib/python3.5/site-packages/tensorflow/python/framework/ops.py in name_scope(name, default_name, values)
#    4148   g = _get_graph_from_inputs(values)
#    4149   with g.as_default(), g.name_scope(n) as scope:
# -> 4150     yield scope
#    4151 # pylint: enable=g-doc-return-or-yield
#    4152
#
# /Users/daniel/anaconda3/envs/tensorflow2/lib/python3.5/contextlib.py in __exit__(self, type, value, traceback)
#      75                 value = type()
#      76             try:
# ---> 77                 self.gen.throw(type, value, traceback)
#      78                 raise RuntimeError("generator didn't stop after throw()")
#      79             except StopIteration as exc:
#
# /Users/daniel/anaconda3/envs/tensorflow2/lib/python3.5/site-packages/tensorflow/python/framework/ops.py in name_scope(self, name)
#    2889         new_stack = self.unique_name(name)
#    2890       self._name_stack = new_stack
# -> 2891       yield "" if new_stack is None else new_stack + "/"
#    2892     finally:
#    2893       self._name_stack = old_stack
#
# /Users/daniel/anaconda3/envs/tensorflow2/lib/python3.5/site-packages/tensorflow/python/framework/ops.py in name_scope(name, default_name, values)
#    4148   g = _get_graph_from_inputs(values)
#    4149   with g.as_default(), g.name_scope(n) as scope:
# -> 4150     yield scope
#    4151 # pylint: enable=g-doc-return-or-yield
#    4152
#
# /Users/daniel/anaconda3/envs/tensorflow2/lib/python3.5/site-packages/tensorflow/python/ops/math_ops.py in binary_op_wrapper(x, y)
#     749       if not isinstance(y, ops.SparseTensor):
#     750         y = ops.convert_to_tensor(y, dtype=x.dtype.base_dtype, name="y")
# --> 751       return func(x, y, name=name)
#     752
#     753   def binary_op_wrapper_sparse(sp_x, y):
#
# /Users/daniel/anaconda3/envs/tensorflow2/lib/python3.5/site-packages/tensorflow/python/ops/gen_math_ops.py in sub(x, y, name)
#    2366     A `Tensor`. Has the same type as `x`.
#    2367   """
# -> 2368   result = _op_def_lib.apply_op("Sub", x=x, y=y, name=name)
#    2369   return result
#    2370
#
# /Users/daniel/anaconda3/envs/tensorflow2/lib/python3.5/site-packages/tensorflow/python/framework/op_def_library.py in apply_op(self, op_type_name, name, **keywords)
#     754           return g.create_op(op_type_name, inputs, output_types, name=scope,
#     755                              input_types=input_types, attrs=attr_protos,
# --> 756                              op_def=op_def)
#
# /Users/daniel/anaconda3/envs/tensorflow2/lib/python3.5/contextlib.py in __exit__(self, type, value, traceback)
#      75                 value = type()
#      76             try:
# ---> 77                 self.gen.throw(type, value, traceback)
#      78                 raise RuntimeError("generator didn't stop after throw()")
#      79             except StopIteration as exc:
#
# /Users/daniel/anaconda3/envs/tensorflow2/lib/python3.5/site-packages/tensorflow/python/framework/ops.py in get_controller(self, default)
#    3643     try:
#    3644       self.stack.append(default)
# -> 3645       yield default
#    3646     finally:
#    3647       if self._enforce_nesting:
#
# /Users/daniel/anaconda3/envs/tensorflow2/lib/python3.5/site-packages/tensorflow/python/framework/op_def_library.py in apply_op(self, op_type_name, name, **keywords)
#     754           return g.create_op(op_type_name, inputs, output_types, name=scope,
#     755                              input_types=input_types, attrs=attr_protos,
# --> 756                              op_def=op_def)
#
# /Users/daniel/anaconda3/envs/tensorflow2/lib/python3.5/contextlib.py in __exit__(self, type, value, traceback)
#      75                 value = type()
#      76             try:
# ---> 77                 self.gen.throw(type, value, traceback)
#      78                 raise RuntimeError("generator didn't stop after throw()")
#      79             except StopIteration as exc:
#
# /Users/daniel/anaconda3/envs/tensorflow2/lib/python3.5/site-packages/tensorflow/python/framework/ops.py in name_scope(name, default_name, values)
#    4148   g = _get_graph_from_inputs(values)
#    4149   with g.as_default(), g.name_scope(n) as scope:
# -> 4150     yield scope
#    4151 # pylint: enable=g-doc-return-or-yield
#    4152
#
# /Users/daniel/anaconda3/envs/tensorflow2/lib/python3.5/contextlib.py in __exit__(self, type, value, traceback)
#      75                 value = type()
#      76             try:
# ---> 77                 self.gen.throw(type, value, traceback)
#      78                 raise RuntimeError("generator didn't stop after throw()")
#      79             except StopIteration as exc:
#
# /Users/daniel/anaconda3/envs/tensorflow2/lib/python3.5/site-packages/tensorflow/python/framework/ops.py in get_controller(self, default)
#    3643     try:
#    3644       self.stack.append(default)
# -> 3645       yield default
#    3646     finally:
#    3647       if self._enforce_nesting:
#
# /Users/daniel/anaconda3/envs/tensorflow2/lib/python3.5/site-packages/tensorflow/python/framework/ops.py in name_scope(name, default_name, values)
#    4148   g = _get_graph_from_inputs(values)
#    4149   with g.as_default(), g.name_scope(n) as scope:
# -> 4150     yield scope
#    4151 # pylint: enable=g-doc-return-or-yield
#    4152
#
# /Users/daniel/anaconda3/envs/tensorflow2/lib/python3.5/contextlib.py in __exit__(self, type, value, traceback)
#      75                 value = type()
#      76             try:
# ---> 77                 self.gen.throw(type, value, traceback)
#      78                 raise RuntimeError("generator didn't stop after throw()")
#      79             except StopIteration as exc:
#
# /Users/daniel/anaconda3/envs/tensorflow2/lib/python3.5/site-packages/tensorflow/python/framework/ops.py in name_scope(self, name)
#    2889         new_stack = self.unique_name(name)
#    2890       self._name_stack = new_stack
# -> 2891       yield "" if new_stack is None else new_stack + "/"
#    2892     finally:
#    2893       self._name_stack = old_stack
#
# /Users/daniel/anaconda3/envs/tensorflow2/lib/python3.5/site-packages/tensorflow/python/framework/ops.py in name_scope(name, default_name, values)
#    4148   g = _get_graph_from_inputs(values)
#    4149   with g.as_default(), g.name_scope(n) as scope:
# -> 4150     yield scope
#    4151 # pylint: enable=g-doc-return-or-yield
#    4152
#
# /Users/daniel/anaconda3/envs/tensorflow2/lib/python3.5/site-packages/tensorflow/python/framework/op_def_library.py in apply_op(self, op_type_name, name, **keywords)
#     754           return g.create_op(op_type_name, inputs, output_types, name=scope,
#     755                              input_types=input_types, attrs=attr_protos,
# --> 756                              op_def=op_def)
#
# /Users/daniel/anaconda3/envs/tensorflow2/lib/python3.5/contextlib.py in __exit__(self, type, value, traceback)
#      75                 value = type()
#      76             try:
# ---> 77                 self.gen.throw(type, value, traceback)
#      78                 raise RuntimeError("generator didn't stop after throw()")
#      79             except StopIteration as exc:
#
# /Users/daniel/anaconda3/envs/tensorflow2/lib/python3.5/site-packages/tensorflow/python/framework/op_def_library.py in _MaybeColocateWith(inputs)
#     252   """
#     253   if not inputs:
# --> 254     yield
#     255   else:
#     256     # NOTE(mrry): The `ops.colocate_with()` function accepts only a single
#
# /Users/daniel/anaconda3/envs/tensorflow2/lib/python3.5/site-packages/tensorflow/python/framework/op_def_library.py in apply_op(self, op_type_name, name, **keywords)
#     747           op = g.create_op(op_type_name, inputs, output_types, name=scope,
#     748                            input_types=input_types, attrs=attr_protos,
# --> 749                            op_def=op_def)
#     750           outputs = op.outputs
#     751           return _Restructure(ops.convert_n_to_tensor(outputs),
#
# /Users/daniel/anaconda3/envs/tensorflow2/lib/python3.5/site-packages/tensorflow/python/framework/ops.py in create_op(self, op_type, inputs, dtypes, input_types, name, attrs, op_def, compute_shapes, compute_device)
#    2337
#    2338     """
# -> 2339     self._check_not_finalized()
#    2340     for idx, a in enumerate(inputs):
#    2341       if not isinstance(a, Tensor):
#
# /Users/daniel/anaconda3/envs/tensorflow2/lib/python3.5/site-packages/tensorflow/python/framework/ops.py in _check_not_finalized(self)
#    2078     """
#    2079     if self._finalized:
# -> 2080       raise RuntimeError("Graph is finalized and cannot be modified.")
#    2081
#    2082   def _add_op(self, op):
#
# RuntimeError: Graph is finalized and cannot be modified.
